# %% [markdown]
# * Elem 1
# * Elem 2
# * Elem 3

# %%
print("hola")

sc.version
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">hola
# Out[14]: &#39;2.4.4&#39;</div>

# %%
rdd1 = sc.textFile("/FileStore/tables/quijote_texto-cd37b.txt")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rdd1.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: 37861</div>

# %%
dbutils.fs.ls("FileStore/tables/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[46]: [FileInfo(path=&#39;dbfs:/FileStore/tables/kmeans_data.txt&#39;, name=&#39;kmeans_data.txt&#39;, size=79),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/quijote_complete.htm&#39;, name=&#39;quijote_complete.htm&#39;, size=89215),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/quijote_texto-cd37b.txt&#39;, name=&#39;quijote_texto-cd37b.txt&#39;, size=2198927)]</div>

# %%
rdd2 = rdd1.map(lambda x:x.replace(',',' ').replace('.',' ').replace('-',' ').replace(':',' ').lower())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rdd1.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: 2</div>

# %%
rdd2.takeSample(False,6)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[30]: [&#39;por estas encrucijadas  cuando veamos más armados que los que vinieron&#39;,
#  &#39;&#39;,
#  &#39;mí!  que me doy a entender  y así es ello la verdad como nací para morir &#39;,
#  &#39;&#39;,
#  &#39;cortesía ninguna  sentóse altisidora en una silla  junto a su cabecera  y &#39;,
#  &#39;&#39;]</div>

# %%
rdd3 = rdd2.flatMap(lambda x: x.split())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rdd3.takeSample(False,6)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[32]: [&#39;and&#39;, &#39;la&#39;, &#39;sola&#39;, &#39;la&#39;, &#39;legua&#39;, &#39;zánganos&#39;]</div>

# %%
rdd3.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[33]: 384757</div>

# %%
rdd4 = rdd3.map(lambda x: (x, 1))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rdd5 = rdd4.reduceByKey(lambda x,y:x+y)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rdd5.takeSample(False,6)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[37]: [(&#39;agravio&#39;, 41),
#  (&#39;entrar&#39;, 88),
#  (&#39;disfrazada&#39;, 2),
#  (&#39;embarazo&#39;, 1),
#  (&#39;acordarme&#39;, 3),
#  (&#39;temíamos&#39;, 2)]</div>

# %%
rdd6 = rdd5.map(lambda x:(x[1],x[0]))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rdd6.takeSample(False,6)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[39]: [(15, &#39;brío&#39;),
#  (3, &#39;trece&#39;),
#  (5, &#39;new&#39;),
#  (4, &#39;quilates&#39;),
#  (1, &#39;entraros&#39;),
#  (3, &#39;soy;&#39;)]</div>

# %%
rdd7 = rdd6.sortByKey(False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rdd7.take(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[42]: [(20593, &#39;que&#39;),
#  (18194, &#39;de&#39;),
#  (18139, &#39;y&#39;),
#  (10358, &#39;la&#39;),
#  (9852, &#39;a&#39;),
#  (8202, &#39;en&#39;),
#  (8199, &#39;el&#39;),
#  (6200, &#39;no&#39;),
#  (4744, &#39;los&#39;),
#  (4691, &#39;se&#39;)]</div>

# %%
from pyspark.sql import SQLContext, Row

# sqlContext already available in Databricks CE

# sqlContext = SQLContext.getOrCreate(sc.getOrCreate())



# Creating a simple DataFrame programatically

array = [Row(key="a", group="vowels", value=1),

         Row(key="b", group="consonants", value=2),

         Row(key="c", group="consonants", value=3),

         Row(key="d", group="consonants", value=4),

         Row(key="e", group="vowels", value=5)]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dataframe = sqlContext.createDataFrame(sc.parallelize(array))

dataframe.registerTempTable("PythonTestTable")



# Visualize (in Databricks cloud - Display() )

display(dataframe)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>group</th><th>key</th><th>value</th></tr></thead><tbody><tr><td>vowels</td><td>a</td><td>1</td></tr><tr><td>consonants</td><td>b</td><td>2</td></tr><tr><td>consonants</td><td>c</td><td>3</td></tr><tr><td>consonants</td><td>d</td><td>4</td></tr><tr><td>vowels</td><td>e</td><td>5</td></tr></tbody></table></div>

# %%
dataframe.registerTempTable('MiTabla')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
select * from MiTabla where key > 'd'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>group</th><th>key</th><th>value</th></tr></thead><tbody><tr><td>vowels</td><td>e</td><td>5</td></tr></tbody></table></div>
